# %%
import numpy as np
import pandas as pd

# %%
data=pd.read_csv('Student.csv')

# %%
data.columns
# Out:
# Index(['Name', 'Sec', 'Roll', 'Marks', 'Grade'], dtype='object')

# %%
data.head()
# Out:
#      Name Sec  Roll  Marks Grade
# 0  Akash    A    34     80     A
# 1  Ankur    A    53     90    A+
# 2  Aditya   C    32     93    O+
# 3  Agniv    B    33     89     O
# 4     Omm   B    70     85     A

# %%
data.head(2)
# Out:
#      Name Sec  Roll  Marks Grade
# 0  Akash    A    34     80     A
# 1  Ankur    A    53     90    A+
