# %%
x1=[3,4,5,6,2]
x2=[8,5,7,3,1]
y=[-3.7,3.5,2.5,11.5,5.7]
X1=sum(x1)/len(x1)
X2=sum(x2)/len(x2)
Y=sum(y)/len(y)
x12sum=0
x22sum=0
x1x2sum=0
x1ysum=0
x2ysum=0
for i in range(len(x1)):
    x12sum+=x1[i]**2
    x22sum+=x2[i]**2
    x1x2sum+=x1[i]*x2[i]
    x1ysum+=x1[i]*y[i]
    x2ysum+=x2[i]*y[i]

print(X1, X2, Y, x12sum, x22sum, x1x2sum, x1ysum, x2ysum)
# Out:
# 4.0 4.8 3.9 90 148 99 95.80000000000001 45.6

# %%
B1 = ((x22sum*x1ysum) - (x1x2sum*x2ysum))/((x12sum*x22sum)-(x1x2sum)**2)

# %%
B2 = ((x12sum*x2ysum) - (x1x2sum*x1ysum))/((x12sum*x22sum)-(x1x2sum)**2)

# %%
B0 = (Y- B1*X1-B2*X2)

# %%
print(B1,B2,B0)
# Out:
# 2.7462347257743676 -1.528900255754476 0.25378232452401406

# %%
# Out:
# Enter x1:  3
# Enter x2:  2

# %%
x1=int(input("Enter x1: "))
x2=int(input("Enter x2: "))
y=B0+B1*x1+B2*x2
print(f"y predicted value for x1 = {x1} and x2 = {x2} = {y:.4f}")
# Out:
# Enter x1:  3
# Enter x2:  2
# y predicted value for x1 = 3 and x2 = 2 = 5.4347

# %%
def multi_regression(X1,X2,Y,n):
    X1_mean = sum(X1)/n
    X2_mean = sum(X2)/n
    Y_mean = sum(Y)/n

    X1_sum = 0
    X2_sum = 0
    X1_X2 = 0
    X1_Y = 0
    X2_Y = 0

    for i in range(n):
        X1_sum += (X1[i]-X1_mean)**2
        X2_sum += (X2[i]-X2_mean)**2
        X1_X2 += (X1[i]-X1_mean) * (X2[i]-X2_mean)
        X1_Y += (X1[i]-X1_mean) * (Y[i]-Y_mean)
        X2_Y += (X2[i]-X2_mean) * (Y[i]-Y_mean)

    print(X1_mean, X2_mean, Y_mean, X1_sum, X2_sum, X1_X2, X1_Y, X2_Y)
    deno = (X1_sum * X2_sum) - (X1_X2)**2
    B1 = (X2_sum * X1_Y - X1_X2 * X2_Y) / deno
    B2 = (X1_sum * X2_Y - X1_X2 * X1_Y) / deno
    B0 = Y_mean - B1 * X1_mean - B2 * X2_mean

    print(f"Gradient B1 : {B1}")
    print(f"Gradient B2 : {B2}")
    print(f"Bias B0 : {B0}")
    print(f"Final Regression Equation : y = {B0} + {B1}x1 + {B2}x2")

    x1 = float(input("Enter the x1 : "))
    x2 = float(input("Enter the x2 : "))

    y = B0 + B1 * x1 + B2 * x2

    print(f"Predicted Value of y at {x1} and {x2} is : {y:.4f}")

def main():
    n = int(input("Enter the no of terms : "))
    X1, X2, Y = [], [], []

    for i in range(n):
        X1.append(float(input(f"Enter X1 {i+1}: ")))
        X2.append(float(input(f"Enter X2 {i+1}: ")))
        Y.append(float(input(f"Enter Y {i+1}: ")))

    multi_regression(X1, X2, Y, n)


main()
# Out:
# Enter the no of terms :  5
# Enter X1 1:  3
# Enter X2 1:  8
# Enter Y 1:  -3.7
# Enter X1 2:  4
# Enter X2 2:  5
# Enter Y 2:  3.5
# Enter X1 3:  5
# Enter X2 3:  7
# Enter Y 3:  2.5
# Enter X1 4:  6
# Enter X2 4:  3
# Enter Y 4:  11.5
# Enter X1 5:  2
# Enter X2 5:  1
# Enter Y 5:  5.7
# 4.0 4.8 3.9 10.0 32.800000000000004 3.0 17.799999999999997 -48.0
# Gradient B1 : 2.2816300940438867
# Gradient B2 : -1.6721003134796235
# Bias B0 : 2.799561128526646
# Final Regression Equation : y = 2.799561128526646 + 2.2816300940438867x1 + -1.6721003134796235x2
# Enter the x1 :  3
# Enter the x2 :  2
# Predicted Value of y at 3.0 and 2.0 is : 6.3003
